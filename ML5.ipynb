# %%
import pandas as pd

rate = [3.99,4.54,6.52,7.91]
r = pd.Series(rate)
r
# Out:
# 0    3.99
# 1    4.54
# 2    6.52
# 3    7.91
# dtype: float64

# %%
r.sum()
# Out:
# 22.96

# %%
r.product()
# Out:
# 934.2278887199999

# %%
r.mean()
# Out:
# 5.74

# %%
r.between(3,5)
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
import pandas as pd
fruits = ["Apple","Mango","Watermelon","Pineapple"]
week = ["Mon","Tue","Wed","Thur"]

pd.Series(fruits,week)
# Out:
# Mon          Apple
# Tue          Mango
# Wed     Watermelon
# Thur     Pineapple
# dtype: object

# %%
pd.Series(data = fruits, index = week)
# Out:
# Mon          Apple
# Tue          Mango
# Wed     Watermelon
# Thur     Pineapple
# dtype: object

# %%
pd.Series(data = week, index = fruits)
# Out:
# Apple          Mon
# Mango          Tue
# Watermelon     Wed
# Pineapple     Thur
# dtype: object

# %%
pd.Series(fruits, index = week)
# Out:
# Mon          Apple
# Tue          Mango
# Wed     Watermelon
# Thur     Pineapple
# dtype: object

# %% [markdown]
# # Read CSV file using pandas

# %%
import pandas as pd
pokemon = pd.read_csv("pokemon.csv")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon = pd.read_csv("pokemon.csv", squeeze=True, usecols=["Name"])
pokemon.head(10)
# Out:
# 0                    Bulbasaur
# 1                      Ivysaur
# 2                     Venusaur
# 3        VenusaurMega Venusaur
# 4                   Charmander
# 5                   Charmeleon
# 6                    Charizard
# 7    CharizardMega Charizard X
# 8    CharizardMega Charizard Y
# 9                     Squirtle
# Name: Name, dtype: object

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
pokemon.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# ...

# %%
pokemon.values
# Out:
# array([[1, 'Bulbasaur', 'Grass', ..., 45, 1, False],
#        [2, 'Ivysaur', 'Grass', ..., 60, 1, False],
#        [3, 'Venusaur', 'Grass', ..., 80, 1, False],
#        ...,
#        [720, 'HoopaHoopa Confined', 'Psychic', ..., 70, 6, True],
#        [720, 'HoopaHoopa Unbound', 'Psychic', ..., 80, 6, True],
#        [721, 'Volcanion', 'Fire', ..., 70, 6, True]], dtype=object)

# %%
pokemon.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
pokemon.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokemon.ndim
# Out:
# 2

# %%
pokemon.shape
# Out:
# (800, 13)

# %%
pokemon.size
# Out:
# 10400

# %%
pokemon.empty
# Out:
# False

# %%
pokemon.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon.Name.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pokemon.Name = "pokemon_new"
pokemon.head()
# Out:
#    #         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1  pokemon_new  Grass  Poison    318  45      49       49       65
# 1  2  pokemon_new  Grass  Poison    405  60      62       63       80
# 2  3  pokemon_new  Grass  Poison    525  80      82       83      100
# 3  3  pokemon_new  Grass  Poison    625  80     100      123      122
# 4  4  pokemon_new   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon.sort_values(by = "HP").head(3)
# Out:
#        #         Name  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 316  292  pokemon_new     Bug  Ghost    236   1      90       45       30
# 55    50  pokemon_new  Ground    NaN    265  10      55       25       35
# 139  129  pokemon_new   Water    NaN    200  20      10       55       15
#
#      Sp. Def  Speed  Generation  Legendary
# 316       30     40           3      False
# 55        45     95           1      False
# 139       20     80           1      False

# %%
pokemon.sort_values(by = "Type 1").head(3)
# Out:
#        #         Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 600  540  pokemon_new    Bug  Grass    310  45      53       70       40
# 136  127  pokemon_new    Bug    NaN    500  65     125      100       55
# 457  412  pokemon_new    Bug    NaN    224  40      29       45       29
#
#      Sp. Def  Speed  Generation  Legendary
# 600       60     42           5      False
# 136       70     85           1      False
# 457       45     36           4      False

# %%
pokemon.sort_values(by = "Attack").head(3)
# Out:
#        #         Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 488  440  pokemon_new  Normal    NaN    220  100       5        5       15
# 121  113  pokemon_new  Normal    NaN    450  250       5        5       35
# 230  213  pokemon_new     Bug   Rock    505   20      10      230       10
#
#      Sp. Def  Speed  Generation  Legendary
# 488       65     30           4      False
# 121      105     50           1      False
# 230      230      5           2      False

# %%
pokemon.sort_values(by = "Attack",ascending = False).head(3)
# Out:
#        #         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163  150  pokemon_new  Psychic  Fighting    780  106     190      100
# 232  214  pokemon_new      Bug  Fighting    600   80     185      115
# 424  383  pokemon_new   Ground      Fire    770  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True
# 232       40      105     75           2      False
# 424      150       90     90           3       True

# %%
pokemon.sort_values(by = "Attack",ascending = False,inplace = True)
pokemon.head()
# Out:
#        #         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163  150  pokemon_new  Psychic  Fighting    780  106     190      100
# 232  214  pokemon_new      Bug  Fighting    600   80     185      115
# 424  383  pokemon_new   Ground      Fire    770  100     180      160
# 429  386  pokemon_new  Psychic       NaN    600   50     180       20
# 426  384  pokemon_new   Dragon    Flying    780  105     180      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True
# 232       40      105     75           2      False
# 424      150       90     90           3       True
# 429      180       20    150           3       True
# 426      180      100    115           3       True

# %%
pokemon.sort_index()
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon.sort_index(ascending = False).head()
# Out:
# 799              Volcanion
# 798     HoopaHoopa Unbound
# 797    HoopaHoopa Confined
# 796    DiancieMega Diancie
# 795                Diancie
# Name: Name, dtype: object

# %%
pokemon.sort_index(ascending = False).tail()
# Out:
# 4               Charmander
# 3    VenusaurMega Venusaur
# 2                 Venusaur
# 1                  Ivysaur
# 0                Bulbasaur
# Name: Name, dtype: object

# %%
pokemon.sort_index(ascending = True).head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object
